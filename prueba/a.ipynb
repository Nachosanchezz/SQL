# %%
import pandas as pd

df = pd.read_csv('r.csv')

# %%
for i in df.columns:
    if df[i].dtype == 'object':
        # Replace commas with dots in string columns
        df[i] = df[i].str.replace(',', '.')
        if df[i].str.contains('.').any():
            try:
                # Convert to float if possible
                df[i] = df[i].astype(float)
            except ValueError:
                # If conversion fails, keep as string
                pass

# %%
df
# Out:
#        Customer_ID  Edad  churn_estimado  retencion_estimado   CLTV_1_anio  \
# 0             5684    26        0.999098        9.020201e-04  3.656132e+00
# 1            23200    35        0.995269        4.730822e-03  1.478271e+01
# 2            71344    40        0.910602        8.939838e-02  1.502561e+02
# 3            26632    48        0.999991        9.349050e-06  5.993899e-02
# 4            78278    33        1.000000        1.600947e-08  1.559631e-04
# ...            ...   ...             ...                 ...           ...
# 44048        86175    43        0.595223        4.047775e-01  1.651946e+02
# 44049        76973    64        0.999847        1.532707e-04  7.741450e-01
# 44050        84170    47        1.000000        1.275509e-08  1.248028e-04
# 44051        54688    45        0.911942        8.805848e-02  9.310497e+01
# 44052        29110    57        1.000000        7.281779e-11  9.131017e-07
#
#        CLTV_2_anios  CLTV_3_anios  CLTV_4_anios  CLTV_5_anios
# 0      3.659227e+00  3.659230e+00  3.659230e+00  3.659230e+00
# 1      1.484835e+01  1.484864e+01  1.484864e+01  1.484864e+01
# 2      1.628640e+02  1.639086e+02  1.639963e+02  1.640036e+02
# 3      5.993951e-02  5.993951e-02  5.993951e-02  5.993951e-02
# 4      1.559631e-04  1.559631e-04  1.559631e-04  1.559631e-04
# ...             ...           ...           ...           ...
# 44048  2.279558e+02  2.515013e+02  2.604499e+02  2.638393e+02
# 44049  7.742563e-01  7.742564e-01  7.742564e-01  7.742564e-01
# 44050  1.248028e-04  1.248028e-04  1.248028e-04  1.248028e-04
# 44051  1.008002e+02  1.014283e+02  1.014802e+02  1.014845e+02
# 44052  9.131017e-07  9.131017e-07  9.131017e-07  9.131017e-07
#
# [44053 rows x 9 columns]
